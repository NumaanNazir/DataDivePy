# %% [markdown]
#                                            PANDAS

# %%
#IMPORTING PANDAS

import pandas as pd

# %%
#READING CSV 

data=pd.read_csv("C:\\Users\\nqnqa\\Downloads\\seattle-weather.csv")

# %%
data
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1     2012-01-02           10.9      10.6       2.8   4.5     rain
# 2     2012-01-03            0.8      11.7       7.2   2.3     rain
# 3     2012-01-04           20.3      12.2       5.6   4.7     rain
# 4     2012-01-05            1.3       8.9       2.8   6.1     rain
# ...          ...            ...       ...       ...   ...      ...
# 1456  2015-12-27            8.6       4.4       1.7   2.9     rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3     rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
data["weather"].value_counts()
# Out:
# weather
# rain       641
# sun        640
# fog        101
# drizzle     53
# snow        26
# Name: count, dtype: int64

# %%
#GROUPBY

data01=data.groupby(["weather"])

# %%
data01

# %%
for weather , weather_data in data01:
    
    print(weather_data)
    
    print(weather)
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 26    2012-01-27            0.0       6.7      -2.2   1.4  drizzle
# 45    2012-02-15            0.0       7.2       0.6   1.8  drizzle
# 85    2012-03-26            0.0      12.8       6.1   4.3  drizzle
# 103   2012-04-13            0.0      15.0       3.9   4.0  drizzle
# 118   2012-04-28            0.0      16.1       8.3   2.5  drizzle
# 135   2012-05-15            0.0      24.4       9.4   4.1  drizzle
# 175   2012-06-24            0.0      19.4       9.4   2.0  drizzle
# 186   2012-07-05            0.0      24.4      10.6   3.1  drizzle
# 191   2012-07-10            0.0      23.9      11.1   2.3  drizzle
# 193   2012-07-12            0.0      25.6      13.3   2.7  drizzle
# 207   2012-07-26            0.0      25.6      12.8   2.2  drizzle
# 208   2012-07-27            0.0      18.9      13.9   2.8  drizzle
# ...

# %%
#Getting Rain 

rain=data01.get_group("rain")

# %%
rain
# Out:
#             date  precipitation  temp_max  temp_min  wind weather
# 1     2012-01-02           10.9      10.6       2.8   4.5    rain
# 2     2012-01-03            0.8      11.7       7.2   2.3    rain
# 3     2012-01-04           20.3      12.2       5.6   4.7    rain
# 4     2012-01-05            1.3       8.9       2.8   6.1    rain
# 5     2012-01-06            2.5       4.4       2.2   2.2    rain
# ...          ...            ...       ...       ...   ...     ...
# 1452  2015-12-23            6.1       5.0       2.8   7.6    rain
# 1453  2015-12-24            2.5       5.6       2.2   4.3    rain
# 1454  2015-12-25            5.8       5.0       2.2   1.5    rain
# 1456  2015-12-27            8.6       4.4       1.7   2.9    rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3    rain
#
# [641 rows x 6 columns]

# %%
#Getting drizzle group

drizzle=data01.get_group("drizzle")

# %%
drizzle.describe()
# Out:
#        precipitation   temp_max   temp_min       wind
# count           53.0  53.000000  53.000000  53.000000
# mean             0.0  15.926415   7.111321   2.367925
# std              0.0   8.812036   6.182191   0.911418
# min              0.0   1.100000  -3.900000   0.600000
# 25%              0.0   8.300000   1.700000   1.800000
# 50%              0.0  16.100000   8.300000   2.100000
# 75%              0.0  23.900000  12.800000   2.700000
# max              0.0  31.700000  16.100000   4.700000
